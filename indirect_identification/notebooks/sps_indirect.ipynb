# %% [markdown]
# # Requirements

# %%
#pip install -r requirements.txt
#pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/cu126

# %% [markdown]
# # Generate ARMAX model

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

class ARMAX:
    def __init__(self, A, B, C, F, L):
        self.A = np.array(A)
        self.B = np.array(B)
        self.C = np.array(C)
        self.F = np.array(F)
        self.L = np.array(L)
    
    def simulate(self, n_samples, R=None, noise_std=0.1):
        Y = np.zeros(n_samples)
        U = np.zeros(n_samples)
        N = np.random.normal(0, noise_std, n_samples)
        
        if R is None:
            R = np.zeros(n_samples)
        
        max_order = max(len(self.A), len(self.B), len(self.C), len(self.F), len(self.L))
        
        for t in range(max_order, n_samples):
            Y[t] = (- np.dot(self.A[1:], Y[t-1:t-len(self.A):-1]) 
                    + np.dot(self.B, U[t-1:t-len(self.B)-1:-1])
                    + np.dot(self.C, N[t:t-len(self.C):-1]))
            
            U[t] = (np.dot(self.L, R[t:t-len(self.L):-1]) 
                    - np.dot(self.F, Y[t:t-len(self.F):-1]))
        
        return Y, U, N, R
    
    def plot_results(self, Y, U, N, R):
        fig, axs = plt.subplots(4, 1, figsize=(10, 12), sharex=True)
        
        axs[0].plot(Y)
        axs[0].set_ylabel('Output (Y)')
        axs[0].set_title('ARMAX Closed-Loop Simulation Results')
        
        axs[1].plot(U)
        axs[1].set_ylabel('Input (U)')
        
        axs[2].plot(N)
        axs[2].set_ylabel('Noise (N)')
        
        axs[3].plot(R)
        axs[3].set_ylabel('Reference (R)')
        axs[3].set_xlabel('Time')
        
        plt.tight_layout()
        plt.show()

# Example usage
A = [1, -0.33]  # A(z^-1) = 1 - 0.33z^-1
B = [0.22]      # B(z^-1) = 0.22z^-1
C = [1, 0.15]   # C(z^-1) = 1 + 0.15z^-1
F = [0.31, 0.23] # F(z^-1) = 0.31 + 0.23z^-1
L = [1]        # L(z^-1) = 1

armax_model = ARMAX(A, B, C, F, L)

n_samples = 100
# square wave reference signal
# R = signal.square(np.linspace(0, 10*np.pi, n_samples))
R = 3*np.ones(n_samples) 
Y, U, N, R = armax_model.simulate(n_samples, R, noise_std=0.2)
armax_model.plot_results(Y, U, N, R)

# %% [markdown]
# # Indirect SPS Implementation

# %%
import os
os.environ['CUPY_ACCELERATORS'] = 'cub'

# %%
# import os
# os.environ['CUPY_ACCELERATORS'] = 'cub'
import torch
try:
    torch.cuda.current_device()
    import cupy as cp
    from cupyx.scipy.linalg import solve_triangular
    from cupyx.scipy.signal import lfilter
    device = 'cuda'
except:
# Fall back to unoptimised versions
    import numpy as cp
    from scipy.linalg import solve_triangular
    from scipy.signal import lfilter
    device = None
    
cp.random.seed(42)
class d_tfs:
    def __init__(self, A):
        self.epsilon = cp.float64(1e-10)
        self.num = cp.asarray(A[0]).astype(self.epsilon.dtype)  # Ensure CuPy array
        self.den = cp.asarray(A[1]).astype(self.epsilon.dtype)   # Ensure CuPy array

    def __mul__(self, other):
        num = cp.convolve(self.num, other.num)  # Use cp.convolve for efficiency
        den = cp.convolve(self.den, other.den)
        return d_tfs((num, den))

    def add_scalar(self, scalar):
        # Multiply the denominator by the scalar
        scalar_denom = scalar * self.den
        # Ensure both polynomials have the same length by padding with zeros at the back
        if len(self.num) > len(scalar_denom):
            scalar_denom = cp.pad(scalar_denom, (0, len(self.num) - len(scalar_denom)))
        elif len(self.num) < len(scalar_denom):
            self.num = cp.pad(self.num, (0, len(scalar_denom) - len(self.num)))
        # Add the polynomials
        num_with_scalar = cp.polyadd(self.num, scalar_denom)
        return d_tfs((num_with_scalar, self.den))

    def __truediv__(self, other):
        num = cp.convolve(self.num, other.den)
        den = cp.convolve(self.den, other.num)
        return d_tfs((num, den))

    def __invert__(self):
        return d_tfs((self.den, self.num))

    def __str__(self):
        return f"Transfer Function: num={self.num}, den={self.den}"

    def __repr__(self):
        return self.__str__()

    def __call__(self, z):
        return cp.polyval(self.num, z) / cp.polyval(self.den, z)

    def apply_shift_operator(self, U_t):
        try:
            # Ensure input is a CuPy array
            U_t = cp.asarray(U_t)
            self.num += self.epsilon  # Add epsilon to avoid division by zero
            self.den += self.epsilon  # Add epsilon to avoid division by zero
            Y_t = lfilter(self.num, self.den, U_t)  # Use lfilter for filtering
            return cp.asarray(Y_t)
        except Exception as e:
            raise ValueError(f"Error applying shift operator: {e}")


class SPS_indirect_model:
    def __init__(self, m, q, N=50):
        self.N = N
        self.m = m
        self.q = q
        self.alpha = cp.random.randn(m,N)
        self.alpha = cp.sign(self.alpha)
        self.alpha[0, :] = 1
        self.pi_order = cp.random.permutation(cp.arange(m))

    def create_phi_optimized(self, Y, U, n_a, n_b):
        m, t = Y.shape
        
        # Initialize phi with zeros
        phi = cp.zeros((m, t, n_a + n_b), dtype=Y.dtype)
        
        # Handle Y lags
        for i in range(1, n_a + 1):
            phi[:, i:, i-1] = -1*Y[:, :-i]
        
        # Handle U lags
        for i in range(1, n_b + 1):
            phi[:, i:, n_a+i-1] = U[:-i]
        
        return phi

    def transform_to_open_loop(self, G, H, F, L):
        G = d_tfs(G)
        H = d_tfs(H)
        F = d_tfs(F)
        L = d_tfs(L)

        GF_plus_I = (G * F).add_scalar(1)
        i_GF_plus_I = ~GF_plus_I
        G_0 = i_GF_plus_I * G * L
        H_0 = i_GF_plus_I * H
        return G_0, H_0

    def open_loop_sps(self, G_0, H_0, Y_t, U_t, n_a, n_b):
        try:
            Y_t = cp.asarray(Y_t)
            U_t = cp.asarray(U_t)
            YGU = Y_t - G_0.apply_shift_operator(U_t)
            N_hat = (~H_0).apply_shift_operator(YGU)

            # last N data points
            N_hat_par = N_hat[-self.N:]
            U_t_par = U_t[-self.N-1:-1]
            
            perturbed_N_hat = cp.multiply(self.alpha, N_hat_par)
            y_bar = [
                G_0.apply_shift_operator(U_t_par) + H_0.apply_shift_operator(perturbed_N_hat[i])
                for i in range(self.m)
            ]

            y_bar = cp.array(y_bar)
            phi_tilde = self.create_phi_optimized(y_bar, U_t_par, n_a, n_b)
            S = cp.zeros(self.m)
            for i in range(self.m):
                phi_col = phi_tilde[i]
                R_i = cp.matmul(phi_col.T, phi_col) / len(Y_t)
                L = cp.linalg.cholesky(R_i)  # Cholesky decomposition to get lower-triangular L
                R_root_inv = solve_triangular(L, cp.eye(L.shape[0]), lower=True)  # Compute L_inv
                weighted_sum = cp.matmul(phi_tilde[i].T,perturbed_N_hat[i].reshape(-1,1))
                # norm squared
                S[i] = cp.sum(cp.square(cp.matmul(R_root_inv, weighted_sum)))

            combined = cp.array(list(zip(self.pi_order, S)))
            order= cp.lexsort(combined.T)
            rank_R = cp.where(order == 0)[0][0] + 1
            return rank_R <= self.m - self.q , S
        except Exception as e:
            raise ValueError(f"Error in open-loop SPS: {e}")
    
    def open_loop_sps_2(self, G_0, H_0, Y_t, U_t, n_a, n_b):
        try:
            Y_t = cp.asarray(Y_t)
            U_t = cp.asarray(U_t)
            YGU = Y_t - G_0.apply_shift_operator(U_t)
            N_hat = (~H_0).apply_shift_operator(YGU)
            
            # Extract relevant segments
            N_hat_par = N_hat[-self.N:]
            U_t_par = U_t[-self.N-1:-1]
            perturbed_N_hat = cp.multiply(self.alpha, N_hat_par)
            
            # Compute y_bar vectorized
            y_bar = G_0.apply_shift_operator(U_t_par)[None, :] + H_0.apply_shift_operator(perturbed_N_hat[:, None])
            y_bar = y_bar.transpose(1, 0, 2)[0]
            
            # Compute phi_tilde
            phi_tilde = self.create_phi_optimized(y_bar, U_t_par, n_a, n_b)
            print(phi_tilde.shape)
            # Compute Cholesky decomposition and norm squared
            R = cp.matmul(phi_tilde.transpose(0, 2, 1), phi_tilde) / len(Y_t)
            L = cp.linalg.cholesky(R)
            Q, R = cp.linalg.qr(L)
            R_root_inv = cp.linalg.solve(R, Q.transpose(0, 2, 1))
            weighted_sum = cp.matmul(phi_tilde.transpose(0, 2, 1), perturbed_N_hat[:, :, None])
            S = cp.sum(cp.square(cp.matmul(R_root_inv, weighted_sum)), axis=(1, 2))
            # Ranking
            combined = cp.array(list(zip(self.pi_order, S)))
            order = cp.lexsort(combined.T)
            rank_R = cp.where(order == 0)[0][0] + 1
            
            return rank_R <= self.m - self.q, S
        except Exception as e:
            raise ValueError(f"Error in open-loop SPS: {e}")
# Example usage with CuPy:
A  = [1, -0.33] # A(z^-1) = 1 - 0.33z^-1
B = [0, 0.22]  # B(z^-1) = 0.22z^-1
C = [1, 0.15] # C(z^-1) = 1 + 0.15z^-1

G = (B, A)  
H = (C, A)     
F = ([0.31, 0.23], [1])  
L = ([1], [1])         

m = 100
q = 5
T = n_samples  # Example sample size

import cProfile, pstats
profiler = cProfile.Profile()

model = SPS_indirect_model(m, q)
G_0, H_0 = model.transform_to_open_loop(G, H, F, L)
# open loop system is 
# Y_t = G_0(z^-1, kappa)U_t + H_0(z^-1, kappa)N_t
# 
in_sps, S1 = model.open_loop_sps_2(G_0=G_0, H_0=H_0, Y_t=Y, U_t=R, n_a=1, n_b=1)
# print(f"SPS: {in_sps}")

profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()
profiler.clear()
# Out:
# (100, 50, 2)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 204
#     201 # print(f"SPS: {in_sps}")
#     203 profiler.disable()
# --> 204 stats = pstats.Stats(profiler).sort_stats('cumtime')
#     205 stats.print_stats()
#     206 profiler.clear()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\pstats.py:115, in Stats.__init__(self, stream, *args)
#     113     arg = args[0]
#     114     args = args[1:]
# --> 115 self.init(arg)
#     116 self.add(*args)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\pstats.py:129, in Stats.init(self, arg)
#     127 self.stats = {}
#     128 self.sort_arg_dict = {}
# --> 129 self.load_stats(arg)
#     130 try:
#     131     self.get_top_level_stats()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\pstats.py:155, in Stats.load_stats(self, arg)
#     153     arg.stats = {}
#     154 if not self.stats:
# --> 155     raise TypeError("Cannot create or construct a %r object from %r"
#     156                     % (self.__class__, arg))
#     157 return
#
# TypeError: Cannot create or construct a <class 'pstats.Stats'> object from <cProfile.Profile object at 0x0000025C89A7ECF0>

# %% [markdown]
# ## Indirect SPS testing

# %%
profiler = cProfile.Profile()
profiler.enable()
in_sps, S1 = model.open_loop_sps(G_0=G_0, H_0=H_0, Y_t=Y, U_t=R, n_a=1, n_b=1)
# print(f"SPS: {in_sps}")

profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()
profiler.clear()
# Out:
#          72853 function calls (72852 primitive calls) in 0.549 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.548    0.274 {built-in method builtins.exec}
#         1    0.001    0.001    0.548    0.548 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\3842388970.py:1(<module>)
#         1    0.046    0.046    0.546    0.546 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:106(open_loop_sps)
#       202    0.027    0.000    0.316    0.002 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:56(apply_shift_operator)
#       202    0.048    0.000    0.286    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_signaltools.py:642(lfilter)
#       202    0.032    0.000    0.152    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_iir_utils.py:532(apply_iir)
#       300    0.010    0.000    0.094    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:539(__call__)
#       202    0.001    0.000    0.047    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters.py:117(convolve1d)
#      1620    0.042    0.000    0.043    0.000 {built-in method cupy._core.core.array}
#       202    0.007    0.000    0.043    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters.py:153(_correlate_or_convolve)
#       202    0.006    0.000    0.042    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_indexing\generate.py:38(__getitem__)
#       302    0.002    0.000    0.042    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:107(eye)
#      1212    0.001    0.000    0.042    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\from_data.py:7(array)
#       300    0.014    0.000    0.031    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:422(_get_args_transposed)
#       202    0.000    0.000    0.031    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_manipulation\join.py:35(concatenate)
#       300    0.001    0.000    0.031    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:388(_apply_func_to_inputs)
#       202    0.030    0.000    0.030    0.000 {built-in method cupy._core._routines_manipulation.concatenate_method}
#       300    0.027    0.000    0.030    0.000 {built-in method cupy._core._routines_linalg.matmul}
#       100    0.002    0.000    0.029    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_decomposition.py:157(cholesky)
#       202    0.011    0.000    0.027    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:115(_call_kernel)
#       100    0.003    0.000    0.024    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\linalg\_solve_triangular.py:10(solve_triangular)
#       506    0.010    0.000    0.023    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:229(zeros)
#       404    0.022    0.000    0.022    0.000 {method 'astype' of 'cupy._core.core._ndarray_base' objects}
#       302    0.016    0.000    0.016    0.000 {method 'fill' of 'cupy._core.core._ndarray_base' objects}
#       905    0.016    0.000    0.016    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:12(empty)
#       202    0.000    0.000    0.015    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\from_data.py:105(ascontiguousarray)
#       202    0.014    0.000    0.014    0.000 {built-in method cupy._core.core.ascontiguousarray}
#       808    0.003    0.000    0.013    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_iir_utils.py:495(_get_module_func)
#       506    0.012    0.000    0.012    0.000 {method 'memset_async' of 'cupy.cuda.memory.MemoryPointer' objects}
#       202    0.011    0.000    0.011    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_arraytools.py:47(axis_assign)
#       302    0.011    0.000    0.011    0.000 {method 'diagonal' of 'cupy._core.core._ndarray_base' objects}
#       100    0.000    0.000    0.010    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_math\sumprod.py:11(sum)
#       202    0.004    0.000    0.010    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:65(empty_like)
#       100    0.009    0.000    0.009    0.000 {method 'sum' of 'cupy._core.core._ndarray_base' objects}
#       808    0.007    0.000    0.007    0.000 {method 'get_function' of 'cupy._core.raw.RawModule' objects}
#       600    0.003    0.000    0.007    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:414(_transpose_element)
#       300    0.005    0.000    0.007    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:47(_validate_normalize_axes)
#       606    0.006    0.000    0.007    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\__init__.py:349(result_type)
#       100    0.005    0.000    0.005    0.000 {built-in method cupy_backends.cuda.libs.cusolver.dpotrf}
#       202    0.002    0.000    0.005    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:60(_check_nd_args)
#       202    0.003    0.000    0.005    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:34(_new_like_order_and_strides)
#       900    0.005    0.000    0.005    0.000 {method 'transpose' of 'cupy._core.core._ndarray_base' objects}
#       100    0.005    0.000    0.005    0.000 {built-in method cupy_backends.cuda.libs.cublas.dtrsm}
#       100    0.005    0.000    0.005    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:160(_tril)
#      8152    0.004    0.000    0.005    0.000 {built-in method builtins.isinstance}
#      1309    0.002    0.000    0.005    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\numeric.py:1855(isscalar)
#       600    0.003    0.000    0.004    0.000 {built-in method cupy._core._routines_manipulation.broadcast_to}
#       202    0.004    0.000    0.004    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_arraytools.py:7(axis_slice)
#      1600    0.002    0.000    0.004    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       202    0.001    0.000    0.004    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:48(_convert_1d_args)
#       300    0.001    0.000    0.003    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:254(determine_dtype)
#     12208    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#       408    0.000    0.000    0.003    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\from_data.py:56(asarray)
#      1010    0.002    0.000    0.003    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_iir_utils.py:11(_get_typename)
#       302    0.003    0.000    0.003    0.000 {method 'reshape' of 'cupy._core.core._ndarray_base' objects}
#       202    0.001    0.000    0.002    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:94(_get_inttype)
#       100    0.001    0.000    0.002    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:60(linalg_common_type)
#       300    0.001    0.000    0.002    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:195(_determine_from_args)
#      3312    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#       300    0.001    0.000    0.001    0.000 {built-in method cupy._core.internal._get_strides_for_order_K}
#       200    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_manipulation\dims.py:132(expand_dims)
#      1500    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#       202    0.001    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:40(_get_output)
#      1010    0.001    0.000    0.001    0.000 {built-in method cupy._core._scalar.get_typename}
#       202    0.001    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:12(_origins_to_offsets)
#       202    0.001    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:31(_get_weights_dtype)
#       300    0.001    0.000    0.001    0.000 {built-in method cupy._core.internal._broadcast_shapes}
#       202    0.001    0.000    0.001    0.000 {built-in method builtins.sum}
#       200    0.001    0.000    0.001    0.000 {built-in method cupy._core._routines_manipulation._expand_dims}
#       100    0.001    0.000    0.001    0.000 {built-in method cupy.cuda.device.get_cusolver_handle}
#       100    0.001    0.000    0.001    0.000 {built-in method cupy.cuda.device.get_cublas_handle}
#       200    0.001    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:102(_common_type_internal)
#       300    0.001    0.000    0.001    0.000 {method '_set_shape_and_strides' of 'cupy._core.core._ndarray_base' objects}
#       802    0.001    0.000    0.001    0.000 {built-in method numpy.promote_types}
#       202    0.001    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:65(_fix_sequence_arg)
#       402    0.000    0.000    0.001    0.000 <frozen abc>:117(__instancecheck__)
#      2400    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#       100    0.001    0.000    0.001    0.000 {built-in method cupy_backends.cuda.libs.cusolver.dpotrf_bufferSize}
#       600    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\function_base.py:348(iterable)
#      1605    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#       300    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:521(_determine_order)
#       606    0.001    0.000    0.001    0.000 {built-in method cupy._core.internal._normalize_axis_index}
#       404    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:99(<genexpr>)
#      1800    0.001    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:415(<genexpr>)
#       900    0.001    0.000    0.001    0.000 {method 'union' of 'set' objects}
#      1206    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       600    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       808    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       404    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:79(_check_origin)
#       402    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#       202    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_misc\memory_ranges.py:30(shares_memory)
#       200    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:17(_assert_cupy_array)
#       202    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:6(_is_integer_output)
#       100    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:109(_check_cusolver_dev_info_if_synchronization_allowed)
#       502    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       900    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:197(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:78(create_phi_optimized)
#      1308    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\multiarray.py:669(result_type)
#       802    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:44(__invert__)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_sorting\search.py:177(where)
#         1    0.000    0.000    0.000    0.000 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:17(__init__)
#       104    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\_internal.py:250(__init__)
#       600    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:417(<genexpr>)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_sorting\search.py:120(nonzero)
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'cupy._core.core._ndarray_base' objects}
#       508    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\multiarray.py:618(min_scalar_type)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_sorting\sort.py:42(lexsort)
#       404    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:13(<genexpr>)
#       202    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:86(_check_mode)
#       202    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._update_order_char}
#       202    0.000    0.000    0.000    0.000 {built-in method cupy._core._memory_range.may_share_bounds}
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\codeop.py:121(__call__)
#       100    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:40(_assert_stacked_square)
#       600    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:492(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method cupy.cuda.thrust.lexsort}
#       300    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       100    0.000    0.000    0.000    0.000 {built-in method cupy._core._fusion_thread_local.is_fusing}
#       202    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:708(__set__)
#       202    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3631(set)
#       202    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:689(set)
#       100    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\_ufunc_config.py:40(get_config_linalg)
#       202    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:14(_check_cval)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       100    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:32(_assert_stacked_2d)
#       104    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\_internal.py:304(data)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'cupy._core.core._ndarray_base' objects}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:718(_validate)
#       200    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\multiarray.py:503(can_cast)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\ipkernel.py:775(_clean_thread_parent_frames)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1523(notify_change)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:299(helper)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3624(validate_elements)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1535(enumerate)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:141(__exit__)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\history.py:839(_writeout_output_cache)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:104(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         7    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1198(ident)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:2304(validate)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#        18    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\typing.py:2187(cast)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\syncdetect.py:36(_declare_synchronize)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3493(compare)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {cupy._util.check_array}
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:1277(user_global_ns)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\syncdetect.py:27(_is_allowed)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'tuple' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       1/0    0.000    0.000    0.000          d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3541(run_code)

# %%
profiler2 = cProfile.Profile()
profiler2.enable()
in_sps, S2 = model.open_loop_sps_2(G_0=G_0, H_0=H_0, Y_t=Y, U_t=R, n_a=1, n_b=1)
print(f"SPS: {in_sps}")
profiler2.disable()
stats = pstats.Stats(profiler2).sort_stats('cumtime')
stats.print_stats()
print(cp.allclose(S1, S2))
# Out:
# SPS: True
#          3455 function calls (3448 primitive calls) in 0.077 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.000    0.000    0.076    0.025 {built-in method builtins.exec}
#         1    0.004    0.004    0.075    0.075 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:142(open_loop_sps_2)
#        34    0.024    0.001    0.027    0.001 {built-in method cupy._core.core.array}
#        21    0.000    0.000    0.027    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\from_data.py:7(array)
#         1    0.000    0.000    0.026    0.026 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_decomposition.py:263(qr)
#         1    0.000    0.000    0.026    0.026 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_decomposition.py:225(_qr_batched)
#         1    0.025    0.025    0.025    0.025 {built-in method cupyx.cusolver._geqrf_orgqr_batched}
#         4    0.000    0.000    0.007    0.002 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:56(apply_shift_operator)
#         4    0.001    0.000    0.006    0.002 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_signaltools.py:642(lfilter)
#         1    0.000    0.000    0.004    0.004 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_sorting\sort.py:42(lexsort)
#         1    0.004    0.004    0.004    0.004 {built-in method cupy.cuda.thrust.lexsort}
#       200    0.000    0.000    0.003    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_manipulation\dims.py:132(expand_dims)
#         4    0.001    0.000    0.003    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_iir_utils.py:532(apply_iir)
#       200    0.001    0.000    0.003    0.000 {built-in method cupy._core._routines_manipulation._expand_dims}
#         3    0.000    0.000    0.003    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:539(__call__)
#       414    0.001    0.000    0.002    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\numeric.py:1855(isscalar)
#         4    0.000    0.000    0.002    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters.py:117(convolve1d)
#         1    0.000    0.000    0.001    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_solve.py:14(solve)
#   754/750    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.001    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\cublas.py:25(batched_gesv)
#       3/1    0.000    0.000    0.001    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3541(run_code)
#         3    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:388(_apply_func_to_inputs)
#         3    0.001    0.000    0.001    0.000 {built-in method cupy._core._routines_linalg.matmul}
#         4    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters.py:153(_correlate_or_convolve)
#       204    0.001    0.000    0.001    0.000 <frozen abc>:117(__instancecheck__)
#         1    0.001    0.001    0.001    0.001 {built-in method builtins.print}
#         2    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_sorting\search.py:177(where)
#         4    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_indexing\generate.py:38(__getitem__)
#         3    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:422(_get_args_transposed)
#         1    0.000    0.000    0.001    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_decomposition.py:157(cholesky)
#         1    0.000    0.000    0.001    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_sorting\search.py:120(nonzero)
#         1    0.000    0.000    0.001    0.001 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_decomposition.py:106(_potrf_batched)
#        13    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\from_data.py:56(asarray)
#         1    0.001    0.001    0.001    0.001 {method 'nonzero' of 'cupy._core.core._ndarray_base' objects}
#         4    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:115(_call_kernel)
#        10    0.001    0.000    0.001    0.000 {method 'astype' of 'cupy._core.core._ndarray_base' objects}
#        20    0.001    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:12(empty)
#         4    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:107(eye)
#         4    0.000    0.000    0.001    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_manipulation\join.py:35(concatenate)
#         4    0.001    0.000    0.001    0.000 {built-in method cupy._core._routines_manipulation.concatenate_method}
#         6    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\from_data.py:105(ascontiguousarray)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:86(_run)
#         1    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\tornado\platform\asyncio.py:200(_handle_events)
#         6    0.000    0.000    0.000    0.000 {built-in method cupy._core.core.ascontiguousarray}
#         9    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:229(zeros)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:583(_handle_events)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'cupy._core.core._ndarray_base' objects}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\ranges.py:9(arange)
#         1    0.000    0.000    0.000    0.000 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:78(create_phi_optimized)
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\codeop.py:121(__call__)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_arraytools.py:47(axis_assign)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\matrix.py:102(tril)
#        16    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_iir_utils.py:495(_get_module_func)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         9    0.000    0.000    0.000    0.000 {method 'memset_async' of 'cupy.cuda.memory.MemoryPointer' objects}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_math\sumprod.py:11(sum)
#         1    0.000    0.000    0.000    0.000 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:44(__invert__)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:65(empty_like)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:624(_handle_recv)
#        16    0.000    0.000    0.000    0.000 {method 'transpose' of 'cupy._core.core._ndarray_base' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\532530477.py:17(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'sum' of 'cupy._core.core._ndarray_base' objects}
#         4    0.000    0.000    0.000    0.000 {method 'fill' of 'cupy._core.core._ndarray_base' objects}
#         4    0.000    0.000    0.000    0.000 {method 'diagonal' of 'cupy._core.core._ndarray_base' objects}
#        12    0.000    0.000    0.000    0.000 {method 'reshape' of 'cupy._core.core._ndarray_base' objects}
#         6    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:414(_transpose_element)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:47(_validate_normalize_axes)
#        16    0.000    0.000    0.000    0.000 {method 'get_function' of 'cupy._core.raw.RawModule' objects}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:556(_run_callback)
#         1    0.000    0.000    0.000    0.000 C:\Users\mukul\AppData\Local\Temp\ipykernel_19856\2658259685.py:1(<module>)
#       204    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\basic.py:34(_new_like_order_and_strides)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:174(_triu)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\ipkernel.py:775(_clean_thread_parent_frames)
#        12    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\__init__.py:349(result_type)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:60(_check_nd_args)
#         1    0.000    0.000    0.000    0.000 {built-in method cupy_backends.cuda.libs.cublas.dgetrsBatched}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\sugar\attrsettr.py:43(__getattr__)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:157(_handle_event)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:655(write)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3631(set)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:60(linalg_common_type)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:587(_schedule_in_thread)
#        17    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:689(set)
#         6    0.000    0.000    0.000    0.000 {built-in method cupy._core._routines_manipulation.broadcast_to}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\tornado\ioloop.py:596(call_later)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_iir_utils.py:503(collapse_2d)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\fromnumeric.py:2979(prod)
#       200    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\multiarray.py:503(can_cast)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:663(_rebuild_io_state)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\fromnumeric.py:71(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\sugar\attrsettr.py:66(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\sugar\socket.py:774(recv_multipart)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_arraytools.py:7(axis_slice)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:48(_convert_1d_args)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:254(determine_dtype)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_creation\matrix.py:78(tri)
#         1    0.000    0.000    0.000    0.000 {built-in method cupy_backends.cuda.libs.cusolver.dpotrfBatched}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\tornado\platform\asyncio.py:210(call_at)
#       132    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method cupy._core._routines_linalg._mat_ptrs}
#        11    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\_internal.py:250(__init__)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:577(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 {built-in method cupy_backends.cuda.libs.cublas.dgetrfBatched}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:259(schedule)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         6    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:102(_common_type_internal)
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\enum.py:1556(__and__)
#        20    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\signal\_iir_utils.py:11(_get_typename)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:686(_update_handler)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\sugar\socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:747(call_later)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:94(_get_inttype)
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:299(helper)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:109(_check_cusolver_dev_info_if_synchronization_allowed)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:195(_determine_from_args)
#         3    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._get_strides_for_order_K}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:771(call_at)
#         5    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:676(__get__)
#        52    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1535(enumerate)
#         3    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._broadcast_shapes}
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\typing.py:392(inner)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1512(_notify_trait)
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:104(__init__)
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:132(__enter__)
#         7    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\enum.py:720(__call__)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:40(_get_output)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:31(_get_weights_dtype)
#        12    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\enum.py:1538(_get_value)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3474(validate)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:12(_origins_to_offsets)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 {built-in method cupy.cuda.device.get_cublas_handle}
#        12    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:492(<genexpr>)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:141(__exit__)
#        20    0.000    0.000    0.000    0.000 {built-in method cupy._core._scalar.get_typename}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\typing.py:1221(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\tornado\ioloop.py:541(time)
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#         3    0.000    0.000    0.000    0.000 {method '_set_shape_and_strides' of 'cupy._core.core._ndarray_base' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1527(_notify_observers)
#        25    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1198(ident)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:65(_fix_sequence_arg)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_manipulation\transpose.py:40(moveaxis)
#        11    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\_internal.py:304(data)
#         6    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\function_base.py:348(iterable)
#        10    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:99(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\typing.py:1492(__subclasscheck__)
#         5    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:629(get)
#        24    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_misc\memory_ranges.py:30(shares_memory)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\enum.py:1545(__or__)
#         1    0.000    0.000    0.000    0.000 {built-in method cupy.cuda.device.get_cusolver_handle}
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:521(_determine_order)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:132(_check_cublas_info_array_if_synchronization_allowed)
#        10    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:79(_check_origin)
#        12    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._normalize_axis_index}
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:738(time)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\typing.py:1285(__hash__)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:542(sending)
#        12    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1222(is_alive)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\_ufunc_config.py:40(get_config_linalg)
#         6    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:505(parent_header)
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\history.py:839(_writeout_output_cache)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\selector_events.py:750(_process_events)
#         9    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:415(<genexpr>)
#        12    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:417(<genexpr>)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:550(_is_master_process)
#         7    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\enum.py:1123(__new__)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\syncdetect.py:36(_declare_synchronize)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:17(_assert_cupy_array)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\queue.py:97(empty)
#        14    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\multiarray.py:618(min_scalar_type)
#        16    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\_gufuncs.py:197(<genexpr>)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:6(_is_integer_output)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        22    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\multiarray.py:669(result_type)
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#        21    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\typing.py:2187(cast)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        10    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_filters_core.py:13(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:1155(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:40(_assert_stacked_square)
#         2    0.000    0.000    0.000    0.000 {built-in method cupy._core._fusion_thread_local.is_fusing}
#         2    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal.prod}
#         4    0.000    0.000    0.000    0.000 {built-in method cupy._core._memory_range.may_share_bounds}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\selectors.py:275(_key_from_fd)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3493(compare)
#         4    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._update_order_char}
#         1    0.000    0.000    0.000    0.000 {cupy._util.check_array}
#         2    0.000    0.000    0.000    0.000 {built-in method cupy._core._routines_manipulation._move_single_axis}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_core\syncdetect.py:27(_is_allowed)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:1277(user_global_ns)
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {method 'count' of 'tuple' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:1907(_add_callback)
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:308(_release_save)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\linalg\_util.py:32(_assert_stacked_2d)
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:86(_check_mode)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3486(validate_elements)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\cublas.py:15(get_batched_gesv_limit)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:127(__lt__)
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         4    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupyx\scipy\ndimage\_util.py:14(_check_cval)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:138(_event_pipe)
#       3/2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:538(receiving)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\dateutil\tz\tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:543(_check_closed)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\core\fromnumeric.py:2974(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:2017(get_debug)
#
#
# True

# %%
import numpy as np

state = np.array([0.0, 0.0, np.pi/4 + 0.1, 0.0])
observable = np.array([[1, 0, 0, 0], [0, 0, 1, 0]])
# only get the observable states by multiplying the state with the observable matrix
o_state = observable @ state

print(o_state)
# Out:
# [0.         0.88539816]

# %%
C = cp.array([1, 0.15])         # C(z^-1) = 1 + 0.15z^-1
F = (cp.array([0.31, 0.23]), cp.array([1]))  # F(z^-1) = 0.31 + 0.23z^-1
L = (cp.array([1]), cp.array([1]))         # L(z^-1) = 1

m = 100
q = 5
T = n_samples
model = SPS_indirect_model(m, q)

# Create arrays for a and b values
a_values = cp.arange(0, 0.4, 0.02)
b_values = cp.arange(0, 0.4, 0.02)

# Create a meshgrid for a and b values
a_grid, b_grid = cp.meshgrid(a_values, b_values, indexing='ij')

# Flatten the grids for iteration
a_flat = a_grid.ravel()
b_flat = b_grid.ravel()

# Store results in a list
results = []

# Create torch tensors directly on GPU
a_torch = torch.tensor(a_flat, dtype=torch.float32, device=device)
b_torch = torch.tensor(b_flat, dtype=torch.float32, device=device)

# Vectorized operations to minimize Python loops
A_torch = torch.stack([torch.ones_like(a_torch), -a_torch], dim=-1)
B_torch = torch.stack([torch.zeros_like(b_torch), b_torch], dim=-1)

# Perform the operations in batch
A = cp.from_dlpack(A_torch)
B = cp.from_dlpack(B_torch)

# Assuming 'model' is predefined and contains the necessary methods
for i in range(len(a_flat)):
    G = (B[i], A[i])  # G should be a tuple of arrays
    H = (C, A[i])  # H should be a tuple of arrays

    # Transform to open loop
    G_0, H_0 = model.transform_to_open_loop(G, H, F, L)  # Assuming F and L are defined

    # Check the condition and store the result if true
    in_sps, S1 = model.open_loop_sps_2(G_0, H_0, Y, R, 1, 1)  # Assuming Y and U are defined
    if in_sps:
        results.append((a_flat[i].item(), b_flat[i].item()))
# Convert the results to a NumPy array
results = np.array(results)
# Plot the results
fig, ax = plt.subplots()
ax.plot(results[:, 0], results[:, 1], 'bo')  # Plot the points as blue dots

# Labeling the plot
ax.set_xlabel('a')
ax.set_ylabel('b')
# axis limits
ax.set_xlim([0, 0.9])
ax.set_ylim([-0.1, 0.5])
ax.set_title('Points for which closed_loop_sps returns True')

# Plot the true values
ax.plot(0.33, 0.22, 'ro')  # Plot the true values as a red dot

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(results[:, 0], results[:, 1], 'bo')  # Plot the points as blue dots

# Labeling the plot
ax.set_xlabel('a')
ax.set_ylabel('b')
# axis limits
ax.set_title('Points for which closed_loop_sps returns True')

# Plot the true values
ax.plot(0.33, 0.22, 'ro')  # Plot the true values as a red dot

# Show the plot
plt.show()

# %% [markdown]
# # Direct SPS implementation

# %%
import os
os.environ['CUPY_ACCELERATORS'] = 'cub'

import os
import torch
try:
    torch.cuda.current_device()
    import cupy as cp
    from cupyx.scipy.linalg import solve_triangular
    from cupyx.scipy.signal import lfilter
except:
    # Fall back to unoptimised versions
    import numpy as cp
    from scipy.linalg import solve_triangular
    from scipy.signal import lfilter
    
cp.random.seed(42)
class d_tfs:
    def __init__(self, A):
        self.epsilon = cp.float64(1e-10)
        self.num = cp.asarray(A[0]).astype(self.epsilon.dtype)  # Ensure CuPy array
        self.den = cp.asarray(A[1]).astype(self.epsilon.dtype)   # Ensure CuPy array

    def __mul__(self, other):
        num = cp.convolve(self.num, other.num)  # Use cp.convolve for efficiency
        den = cp.convolve(self.den, other.den)
        return d_tfs((num, den))

    def add_scalar(self, scalar):
        # Multiply the denominator by the scalar
        scalar_denom = scalar * self.den
        # Ensure both polynomials have the same length by padding with zeros at the back
        if len(self.num) > len(scalar_denom):
            scalar_denom = cp.pad(scalar_denom, (0, len(self.num) - len(scalar_denom)))
        elif len(self.num) < len(scalar_denom):
            self.num = cp.pad(self.num, (0, len(scalar_denom) - len(self.num)))
        # Add the polynomials
        num_with_scalar = cp.polyadd(self.num, scalar_denom)
        return d_tfs((num_with_scalar, self.den))

    def __truediv__(self, other):
        num = cp.convolve(self.num, other.den)
        den = cp.convolve(self.den, other.num)
        return d_tfs((num, den))

    def __invert__(self):
        return d_tfs((self.den, self.num))

    def __str__(self):
        return f"Transfer Function: num={self.num}, den={self.den}"

    def __repr__(self):
        return self.__str__()

    def __call__(self, z):
        return cp.polyval(self.num, z) / cp.polyval(self.den, z)

    def apply_shift_operator(self, U_t):
        try:
            # Ensure input is a CuPy array
            U_t = cp.asarray(U_t)
            self.num += self.epsilon  # Add epsilon to avoid division by zero
            self.den += self.epsilon  # Add epsilon to avoid division by zero
            Y_t = lfilter(self.num, self.den, U_t)  # Use lfilter for filtering
            return cp.asarray(Y_t)
        except Exception as e:
            raise ValueError(f"Error applying shift operator: {e}")


class SPS_direct_model:
    def __init__(self, m, q, N=50):
        self.N = N
        self.m = m
        self.q = q
        self.alpha = cp.random.randn(m,N)
        self.alpha = cp.sign(self.alpha)
        self.alpha[0, :] = 1
        self.pi_order = cp.random.permutation(cp.arange(m))

    def create_phi_optimized(self, Y, U, n_a, n_b):
        m, t = Y.shape
        
        # Initialize phi with zeros
        phi = cp.zeros((m, t, n_a + n_b), dtype=Y.dtype)
        
        # Handle Y lags
        for i in range(1, n_a + 1):
            phi[:, i:, i-1] = -1*Y[:, :-i]
        
        # Handle U lags
        for i in range(1, n_b + 1):
            phi[:, i:, n_a+i-1] = U[:-i]
        
        return phi
    
    # Returns (u_bar, Y_tilde) tuple
    def direct_sps(self, G, H, F, L, Y_t, R_t, n_a, n_b):
        G = d_tfs(G)
        H = d_tfs(H)
        F = d_tfs(F)
        L = d_tfs(L)
        
        try:
            Y_t = cp.asarray(Y_t)
            R_t = cp.asarray(R_t)

            # Regenerate the inputs
            N_hat = self.calculate_Nt(G, H, F, L, Y_t, R_t)
            N_hat_par = N_hat[-self.N:]

            # Perturb the inputs
            N_hat_bar = cp.multiply(self.alpha, N_hat_par)

            U_bar = self.calculate_U_bar(F, L, Y_t, R_t)
            U_bar_par = U_bar[-self.N-1:-1]
            
            Y_tilde = self.calculate_Y_bar(G, H, F, L, U_bar_par, N_hat_bar)
            Y_tilde = cp.asarray(Y_tilde)
            phi_tilde = self.create_phi_optimized(Y_tilde, U_bar_par, n_a, n_b)
            
            # Calculate SPS with new system inputs
            S = cp.zeros(self.m)
            for i in range(self.m):
                phi_col = phi_tilde[i]
                R_i = cp.matmul(phi_col.T, phi_col) / Y_tilde.shape[1]
                L = cp.linalg.cholesky(R_i)  # Cholesky decomposition to get lower-triangular L
                R_root_inv = solve_triangular(L, cp.eye(L.shape[0]), lower=True)  # Compute L_inv
                weighted_sum = cp.matmul(phi_tilde[i].T,N_hat_bar[i].reshape(-1,1))
                # norm squared
                S[i] = cp.sum(cp.square(cp.matmul(R_root_inv, weighted_sum)))

            combined = cp.array(list(zip(self.pi_order, S)))
            order= cp.lexsort(combined.T)
            rank_R = cp.where(order == 0)[0][0] + 1
            return rank_R <= self.m - self.q , S

        except Exception as e:
            print(e)
            pass

    def calculate_Nt(self, G: d_tfs, H: d_tfs, F: d_tfs, L: d_tfs, Y_t: cp.array, R_t: cp.array):
        # N_hat = H^-1*[(1+G*F)*Y_t - G*L*R_t]
        try:

            GLR = G.apply_shift_operator(L.apply_shift_operator(R_t))
            
            YGU = Y_t + F.apply_shift_operator(G.apply_shift_operator(Y_t)) - GLR
            N_hat = (~H).apply_shift_operator(YGU)

            return N_hat
        except Exception as e:
            raise ValueError(f"Error in direct SPS: {e}")

    def calculate_U_bar(self, F: d_tfs, L: d_tfs, Y_t: cp.array, R_t: cp.array):
        # U_bar = L*R_t - FY_bar
        try:

            U_bar = L.apply_shift_operator(R_t) - F.apply_shift_operator(Y_t)

            return U_bar
        except Exception as e:
            raise ValueError(f"Error in direct SPS: {e}")

    def calculate_Y_bar(self, G: d_tfs, H: d_tfs, F: d_tfs, L: d_tfs, U_bar: cp.array, N_t: cp.array):
        try:            
            Y_bar = [
                G.apply_shift_operator(U_bar) + (~H).apply_shift_operator(N_t[i])
                for i in range(self.m)
            ]

            return Y_bar
        except Exception as e:
            raise ValueError(f"Error in direct SPS: {e}")
        
        
# Example usage with CuPy:
A  = [1, -0.33]
B = [0, 0.22]
C = [1, 0.15]

G = (B, A)  
H = (C, A)     
F = ([0.31, 0.23], [1])  
L = ([1], [1])         

m = 100
q = 5
T = n_samples  # Example sample size

import cProfile, pstats
profiler = cProfile.Profile()

direct_model = SPS_direct_model(m, q)


# open loop system is 
# Y_t = G_0(z^-1, kappa)U_t + H_0(z^-1, kappa)N_t
profiler.enable()
in_sps, S1 = direct_model.direct_sps(G, H, F, L, Y, U, 1, 1)
# print(f"SPS: {in_sps}")

profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()
profiler.clear()
# Out:
#          15143 function calls (14931 primitive calls) in 0.009 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.001    0.001    0.008    0.004 {method '__exit__' of 'sqlite3.Connection' objects}
#       100    0.000    0.000    0.003    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\_basic.py:411(solve_triangular)
#         1    0.000    0.000    0.002    0.002 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:164(calculate_Y_bar)
#       207    0.000    0.000    0.002    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:1980(lfilter)
#       100    0.001    0.000    0.002    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\_basic.py:503(_solve_triangular)
#       621    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:96(_reject_objects)
#       100    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:740(cholesky)
#       200    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\_lib\_util.py:491(_asarray_validated)
#       621    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numerictypes.py:471(issubdtype)
#       200    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:579(asarray_chkfinite)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:2338(sum)
#       300    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1242    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numerictypes.py:289(issubclass_)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:69(_wrapreduction)
#       200    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_methods.py:67(_all)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_twodim_base_impl.py:163(eye)
#       203    0.000    0.000    0.000    0.000 {built-in method scipy.signal._sigtools._linear_filter}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_shape_base_impl.py:274(apply_along_axis)
#      2165    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#     206/3    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:58(apply_shift_operator)
#       101    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:46(__invert__)
#       414    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\shape_base.py:21(atleast_1d)
#       105    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:19(__init__)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:148(_commonType)
#      1572    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_ufunc_config.py:440(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:154(calculate_U_bar)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\blas.py:384(getter)
#       310    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_index_tricks_impl.py:690(__init__)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:123(_makearray)
#   560/556    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py:86(_run)
#         1    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_ufunc_config.py:456(__exit__)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\tornado\ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:685(<lambda>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:574(_handle_events)
#       753    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:654(_rebuild_io_state)
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\sparse\_base.py:1400(issparse)
#       114    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       306    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\ma\core.py:6732(isMaskedArray)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\codeop.py:121(__call__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:677(_update_handler)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:2158(<lambda>)
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:128(isComplexType)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:37(as_strided)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       100    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath._make_extobj}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3631(set)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:772(convolve)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:142(_realType)
#         3    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\sugar\attrsettr.py:43(__getattr__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:689(set)
#       100    0.000    0.000    0.000    0.000 {method 'reset' of '_contextvars.ContextVar' objects}
#       100    0.000    0.000    0.000    0.000 {method 'set' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:1(<module>)
#       418    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         1    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:80(create_phi_optimized)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:64(zeros_like)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:198(_assert_stacked_square)
#       414    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\shape_base.py:17(_atleast_1d_dispatcher)
#        17    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:615(_handle_recv)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:192(_assert_stacked_2d)
#       100    0.000    0.000    0.000    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\sugar\attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:718(_validate)
#         5    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\enum.py:1556(__and__)
#       200    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#       100    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       115    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\sugar\socket.py:780(recv_multipart)
#         1    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:97(direct_sps)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_ufunc_config.py:430(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath.correlate}
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:630(transpose)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:2333(_sum_dispatcher)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_shape_base_impl.py:377(<genexpr>)
#     16/12    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\tornado\platform\asyncio.py:225(add_callback)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1512(_notify_trait)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\_misc.py:181(_datacopied)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\typing.py:1221(__instancecheck__)
#        21    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\enum.py:1538(_get_value)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:736(_cholesky_dispatcher)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1523(notify_change)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:51(_wrapfunc)
#        11    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\enum.py:720(__call__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\typing.py:1492(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1527(_notify_observers)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_index_tricks_impl.py:717(__next__)
#         3    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\typing.py:392(inner)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:784(call_soon)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:533(sending)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:299(helper)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\queue.py:97(empty)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:547(_run_callback)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:813(_call_soon)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\enum.py:1545(__or__)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3624(validate_elements)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\history.py:839(_writeout_output_cache)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:104(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:132(__enter__)
#        11    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\enum.py:1123(__new__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\typing.py:1285(__hash__)
#         8    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:733(time)
#         4    0.000    0.000    0.000    0.000 {method 'wrap' of 'numpy._core._multiarray_umath._array_converter' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py:36(__init__)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:24(_maybe_view_as_subclass)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:4591(_validate_x)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\threading.py:314(_is_owned)
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3486(validate_elements)
#        19    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\typing.py:2183(cast)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3493(compare)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\threading.py:308(_release_save)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:626(_transpose_dispatcher)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\ipykernel\iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:459(lexsort)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:58(_zeros_like_dispatcher)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.lib.array_utils.normalize_axis_index}
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:107(empty_like)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:1098(copyto)
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:19(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\zmq\eventloop\zmqstream.py:529(receiving)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:690(result_type)
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:1277(user_global_ns)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:768(_convolve_dispatcher)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_index_tricks_impl.py:698(__iter__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py:750(_process_events)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_shape_base_impl.py:270(_apply_along_axis_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:538(_check_closed)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:383(where)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:2010(get_debug)
#       1/0    0.000    0.000    0.000          c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3541(run_code)

# %% [markdown]
# ## Direct SPS testing

# %%
profiler = cProfile.Profile()
profiler.enable()
in_sps, S1 = direct_model.direct_sps(G, H, F, L, Y, U, 1, 1)
# print(f"SPS: {in_sps}")

profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()
profiler.clear()
# Out:
#          14966 function calls (14961 primitive calls) in 0.015 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.005    0.002    0.010    0.005 {built-in method builtins.exec}
#         1    0.000    0.000    0.006    0.006 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\2466995946.py:1(<module>)
#         1    0.001    0.001    0.006    0.006 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:97(direct_sps)
#       207    0.000    0.000    0.004    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\724668055.py:58(apply_shift_operator)
#         1    0.000    0.000    0.004    0.004 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:164(calculate_Y_bar)
#       207    0.000    0.000    0.004    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:1980(lfilter)
#       621    0.000    0.000    0.003    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:96(_reject_objects)
#       100    0.000    0.000    0.003    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\_basic.py:411(solve_triangular)
#       621    0.000    0.000    0.002    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numerictypes.py:471(issubdtype)
#      1242    0.002    0.000    0.002    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numerictypes.py:289(issubclass_)
#       100    0.001    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\_basic.py:503(_solve_triangular)
#       100    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:740(cholesky)
#       200    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\_lib\_util.py:491(_asarray_validated)
#       200    0.000    0.000    0.001    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:579(asarray_chkfinite)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:2338(sum)
#       300    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:141(calculate_Nt)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:69(_wrapreduction)
#       200    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       203    0.000    0.000    0.000    0.000 {built-in method scipy.signal._sigtools._linear_filter}
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_methods.py:67(_all)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_twodim_base_impl.py:163(eye)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_shape_base_impl.py:274(apply_along_axis)
#      2163    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       101    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\724668055.py:46(__invert__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:154(calculate_U_bar)
#       105    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\724668055.py:19(__init__)
#       414    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\shape_base.py:21(atleast_1d)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:148(_commonType)
#      1572    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_ufunc_config.py:440(__enter__)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\blas.py:384(getter)
#       310    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_index_tricks_impl.py:690(__init__)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:123(_makearray)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_ufunc_config.py:456(__exit__)
#       747    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\codeop.py:121(__call__)
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\sparse\_base.py:1400(issparse)
#       306    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       114    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:708(__set__)
#       516    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       100    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3631(set)
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\ma\core.py:6732(isMaskedArray)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:37(as_strided)
#       200    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:128(isComplexType)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:689(set)
#       100    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath._make_extobj}
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:142(_realType)
#       100    0.000    0.000    0.000    0.000 {method 'reset' of '_contextvars.ContextVar' objects}
#       100    0.000    0.000    0.000    0.000 {method 'set' of '_contextvars.ContextVar' objects}
#        17    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:198(_assert_stacked_square)
#       418    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:64(zeros_like)
#         1    0.000    0.000    0.000    0.000 C:\Users\Jake\AppData\Local\Temp\ipykernel_28088\1119117971.py:80(create_phi_optimized)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_shape_base_impl.py:377(<genexpr>)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:2158(<lambda>)
#       414    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\shape_base.py:17(_atleast_1d_dispatcher)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:718(_validate)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:192(_assert_stacked_2d)
#       100    0.000    0.000    0.000    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:772(convolve)
#       100    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:141(__exit__)
#       200    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#       112    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\_ufunc_config.py:430(__init__)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1512(_notify_trait)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:630(transpose)
#     16/12    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_index_tricks_impl.py:717(__next__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1523(notify_change)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\linalg\_linalg.py:736(_cholesky_dispatcher)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:2333(_sum_dispatcher)
#       100    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\linalg\_misc.py:181(_datacopied)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy._core._multiarray_umath.correlate}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:676(__get__)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:51(_wrapfunc)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:299(helper)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\history.py:839(_writeout_output_cache)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:104(__init__)
#         8    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:2304(validate)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:24(_maybe_view_as_subclass)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\threading.py:314(_is_owned)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\scipy\signal\_signaltools.py:4591(_validate_x)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\threading.py:299(__enter__)
#        18    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\typing.py:2183(cast)
#         4    0.000    0.000    0.000    0.000 {method 'wrap' of 'numpy._core._multiarray_umath._array_converter' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\AppData\Local\Programs\Python\Python312\Lib\threading.py:308(_release_save)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\traitlets\traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:459(lexsort)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:1098(copyto)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:58(_zeros_like_dispatcher)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.lib.array_utils.normalize_axis_index}
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3493(compare)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:626(_transpose_dispatcher)
#         2    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:1277(user_global_ns)
#         8    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:107(empty_like)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:19(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\numeric.py:768(_convolve_dispatcher)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_index_tricks_impl.py:698(__iter__)
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\lib\_shape_base_impl.py:270(_apply_along_axis_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:690(result_type)
#         1    0.000    0.000    0.000    0.000 c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\numpy\_core\multiarray.py:383(where)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       1/0    0.000    0.000    0.000          c:\Users\Jake\Learning-Dynamic-Systems\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3541(run_code)

# %%
import os
os.environ['CUPY_ACCELERATORS'] = 'cub'

import os
import torch
try:
    torch.cuda.current_device()
    import cupy as cp
    device = 'cuda'
except:
    # Fall back to unoptimised versions
    import numpy as cp
    device = None

C = cp.array([1, 0.15])         # C(z^-1) = 1 + 0.15z^-1
F = (cp.array([0.31, 0.23]), cp.array([1]))  # F(z^-1) = 0.31 + 0.23z^-1
L = (cp.array([1]), cp.array([1]))         # L(z^-1) = 1

m = 100
q = 5
T = n_samples
direct_model = SPS_direct_model(m, q)

# Create arrays for a and b values
a_values = cp.arange(0, 0.6, 0.02)
b_values = cp.arange(0, 0.6, 0.02)

# Create a meshgrid for a and b values
a_grid, b_grid = cp.meshgrid(a_values, b_values, indexing='ij')

# Flatten the grids for iteration
a_flat = a_grid.ravel()
b_flat = b_grid.ravel()

# Store results in a list
results = []

# Create torch tensors directly on GPU
a_torch = torch.tensor(a_flat, dtype=torch.float32, device=device)
b_torch = torch.tensor(b_flat, dtype=torch.float32, device=device)

# Vectorized operations to minimize Python loops
A_torch = torch.stack([torch.ones_like(a_torch), -a_torch], dim=-1)
B_torch = torch.stack([torch.zeros_like(b_torch), b_torch], dim=-1)

# Perform the operations in batch
A = cp.from_dlpack(A_torch)
B = cp.from_dlpack(B_torch)

# Assuming 'model' is predefined and contains the necessary methods
for i in range(len(a_flat)):
    G = (B[i], A[i])  # G should be a tuple of arrays
    H = (C, A[i])  # H should be a tuple of arrays

    # Check the condition and store the result if true
    in_sps, S1 = direct_model.direct_sps(G, H, F, L, Y, U, 1, 1)
    if in_sps:
        results.append((a_flat[i].item(), b_flat[i].item()))

# Convert the results to a NumPy array
results = np.array(results)
# Plot the results
fig, ax = plt.subplots()
ax.plot(results[:, 0], results[:, 1], 'bo')  # Plot the points as blue dots

# Labeling the plot
ax.set_xlabel('a')
ax.set_ylabel('b')
# axis limits
ax.set_xlim([-0.1, 1])
ax.set_ylim([-0.1, 1])
ax.set_title('Points for which closed_loop_sps returns True')

# Plot the true values
ax.plot(0.33, 0.22, 'ro')  # Plot the true values as a red dot

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(results[:, 0], results[:, 1], 'bo')  # Plot the points as blue dots

# Labeling the plot
ax.set_xlabel('a')
ax.set_ylabel('b')
# axis limits
ax.set_title('Points for which closed_loop_sps returns True')

# Plot the true values
ax.plot(0.33, 0.22, 'ro')  # Plot the true values as a red dot

# Show the plot
plt.show()

# %% [markdown]
# # testing new sps_indirect class with fast dtfs

# %%
import sys
from pathlib import Path

# Get the current notebook's directory
parent = Path().resolve()  # Current working directory (notebook's directory)
root = parent.parent.parent     # Go one level up

print("Current Directory:", parent)
print("Parent Directory:", root)

# Optionally append to sys.path
sys.path.append(str(root))
# Out:
# Current Directory: D:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\indirect_identification\notebooks
# Parent Directory: D:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems

# %%
from indirect_identification.sps_indirect import SPS_indirect_model
import numpy as np
import matplotlib.pyplot as plt

# 
np.random.seed(42)
# Example usage with CuPy:
A  = [1, -0.33] # A(z^-1) = 1 - 0.33z^-1
B = [0, 0.22]  # B(z^-1) = 0.22z^-1
C = [1, 0.15] # C(z^-1) = 1 + 0.15z^-1

m = 100
q = 5
T = n_samples  # Example sample size

C = np.array([1, 0.15])  # C(z^-1) = 1 + 0.15z^-1
F = (np.array([0.31, 0.23]), np.array([1]))  # F(z^-1) = 0.31 + 0.23z^-1
L = (np.array([1]), np.array([1]))  # L(z^-1) = 1

m = 100
q = 5
T = n_samples

model = SPS_indirect_model(m, q)

# Create arrays for a and b values
a_values = np.arange(0, 0.4, 0.02)
b_values = np.arange(0, 0.4, 0.02)

# Create a meshgrid for a and b values
a_grid, b_grid = np.meshgrid(a_values, b_values, indexing='ij')

# Flatten the grids for iteration
a_flat = a_grid.ravel()
b_flat = b_grid.ravel()

# Store results in a list
results = []

# Vectorized operations to minimize Python loops
A = np.stack([np.ones_like(a_flat), -a_flat], axis=-1)
B = np.stack([np.zeros_like(b_flat), b_flat], axis=-1)

# Perform computations
for i in range(len(a_flat)):
    G = (B[i], A[i])  # G should be a tuple of arrays
    H = (C, A[i])  # H should be a tuple of arrays
    
    # Transform to open loop
    G_0, H_0 = model.transform_to_open_loop(G, H, F, L)  # Assuming F and L are defined

    # Check the condition and store the result if true
    in_sps, S1 = model.open_loop_sps(G_0, H_0, Y, R, 1, 1)  # Assuming Y and U are defined
    if in_sps:
        results.append((a_flat[i], b_flat[i]))

# Convert the results to a NumPy array
results = np.array(results)

# Plot the results
fig, ax = plt.subplots()
ax.plot(results[:, 0], results[:, 1], 'bo')  # Plot the points as blue dots

# Labeling the plot
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_xlim([0, 0.9])
ax.set_ylim([-0.1, 0.5])
ax.set_title('Points for which closed_loop_sps returns True')

# Plot the true values
ax.plot(0.33, 0.22, 'ro')  # Plot the true values as a red dot

# Show the plot
plt.show()

# %% [markdown]
# # benchmarks for different functions

# %%
from cupyx.profiler import benchmark
def create_phi():
    """
    Constructs a 3D array phi of shape (m, t, n_a + n_b) from input arrays Y and U.
    
    Parameters:
    - Y: CuPy array of shape (m, t), where m is the number of sequences and t is the length of each sequence.
    - U: CuPy array of shape (t,), representing the input sequence.
    - n_a: Integer, the number of previous values of Y to include in each phi_t.
    - n_b: Integer, the number of previous values of U to include in each phi_t.
    
    Returns:
    - phi: CuPy array of shape (m, t, n_a + n_b), the constructed 3D array.
    """
    # Example data
    m = 5  # Number of sequences
    t = 20  # Length of each sequence
    n_a = 3  # Number of previous values of Y
    n_b = 2  # Number of previous values of U

    # Create example CuPy arrays for Y and U
    Y = cp.random.rand(m, t)
    U = cp.random.rand(t)
    print(Y[0])
    print(U)

    def create_phi_optimized(Y, U, n_a, n_b):
        m, t = Y.shape
        
        # Initialize phi with zeros
        phi = cp.zeros((m, t, n_a + n_b), dtype=Y.dtype)
        
        # Handle Y lags
        for i in range(1, n_a + 1):
            phi[:, i:, i-1] = Y[:, :-i]
        
        # Handle U lags
        for i in range(1, n_b + 1):
            phi[:, i:, n_a+i-1] = U[:-i]
        
        return phi
    def create_phi_optimized_2(Y, U, n_a, n_b):
        m, t = Y.shape
        
        # Initialize phi with zeros
        phi = cp.zeros((m, t, n_a + n_b), dtype=Y.dtype)
        
        # Create index arrays
        y_indices = cp.arange(t)[:, None] - cp.arange(1, n_a + 1)
        u_indices = cp.arange(t)[:, None] - cp.arange(1, n_b + 1)
        
        # Clip indices to valid range
        y_indices = cp.clip(y_indices, 0, t - 1)
        u_indices = cp.clip(u_indices, 0, t - 1)
        
        # Create mask for valid entries
        y_mask = (cp.arange(t)[:, None] >= cp.arange(1, n_a + 1)).astype(Y.dtype)
        u_mask = (cp.arange(t)[:, None] >= cp.arange(1, n_b + 1)).astype(U.dtype)
        
        # Fill Y lags
        phi[:, :, :n_a] = Y[:, y_indices] * y_mask
        
        # Fill U lags
        phi[:, :, n_a:] = U[u_indices] * u_mask
        
        return phi

    methods = [create_phi_optimized, create_phi_optimized_2]
    for method in methods:
        print(f"Method: {method.__name__}")
        print(benchmark(method, (Y, U, n_a, n_b), n_repeat=1000))
    




        # Initialize phi with zeros
    # phi = cp.zeros((Y.shape[0], Y.shape[1], n_a + n_b), dtype=Y.dtype)
    # # Fill phi with the appropriate lagged values
    # for t in range(min(n_a, n_b), Y.shape[1]):
    #     # Extract the previous n_a values of Y
    #     Y_lags = cp.zeros((Y.shape[0], n_a), dtype=Y.dtype)
    #     if t >= n_a:
    #         Y_lags[:, :] = Y[:, t-n_a:t]
        
    #     # Extract the previous n_b values of U
    #     U_lags = cp.zeros((n_b,), dtype=U.dtype)
    #     if t >= n_b:
    #         U_lags[:] = U[t-n_b:t]
    #     U_lags = cp.tile(U_lags[None, :], (Y.shape[0], 1))
    #     # Concatenate Y_lags and U_lags to form phi_t
    #     phi_t = cp.concatenate([Y_lags, U_lags ], axis=1)
    #     # Store phi_t in the corresponding slice of phi
    #     print(t-max(n_a, n_b))
    #     phi[:, t, :] = phi_t



# Create phi
create_phi()
# Out:
# [0.83563212 0.45545616 0.20276454 0.00221818 0.856313   0.44175708
#  0.68984781 0.05433224 0.42697821 0.19565076 0.33039593 0.97315701
#  0.5468635  0.86663865 0.21054968 0.93884639 0.63208523 0.8614563
#  0.31144366 0.57810279]
# [0.7833139  0.1821845  0.72398885 0.77988199 0.57536508 0.95228893
#  0.03658332 0.2406056  0.61153948 0.22965813 0.86163331 0.32835235
#  0.8361165  0.22372303 0.20211115 0.6844918  0.00209324 0.18962914
#  0.67935658 0.2658095 ]
# Method: create_phi_optimized
# create_phi_optimized:    CPU:   332.399 us   +/- 70.580 (min:   219.700 / max:  1257.200) us     GPU-0:   375.658 us   +/- 240.860 (min:    65.408 / max:  2463.552) us
# Method: create_phi_optimized_2
# create_phi_optimized_2:    CPU:  1819.945 us   +/- 243.100 (min:  1468.400 / max:  3586.600) us     GPU-0:  1931.202 us   +/- 525.659 (min:   299.584 / max:  4778.432) us

# %%
from cupyx.profiler import benchmark

def method_1(Y, U, n_a, n_b):
    """
    Constructs the phi array using a loop-based approach.
    """
    m, t = Y.shape
    phi = cp.zeros((m, t, n_a + n_b), dtype=Y.dtype)
    for i in range(n_a, t):
        Y_lags = Y[:, i - n_a:i]
        U_lags = U[i - n_b:i]
        phi[:, i, :] = cp.concatenate([Y_lags, U_lags[None, :]], axis=1)
    return phi


def method_1(Y, U, n_a, n_b):
    """
    Constructs a 3D array phi of shape (m, t, n_a + n_b) from input arrays Y and U.
    
    Parameters:
    - Y: CuPy array of shape (m, t), where m is the number of sequences and t is the length of each sequence.
    - U: CuPy array of shape (t,), representing the input sequence.
    - n_a: Integer, the number of previous values of Y to include in each phi_t.
    - n_b: Integer, the number of previous values of U to include in each phi_t.
    
    Returns:
    - phi: CuPy array of shape (m, t, n_a + n_b), the constructed 3D array.
    """
    # Initialize phi with zeros
    m , t = Y.shape
    phi = cp.zeros((m, t, n_a + n_b), dtype=Y.dtype)
    # Fill phi with the appropriate lagged values
    for t in range(min(n_a, n_b)-1, Y.shape[1]):
        # Extract the previous n_a values of Y
        Y_lags = cp.zeros((m, n_a), dtype=Y.dtype)
        if t >= n_a-1:
            Y_lags[:, :] = Y[:, t-n_a:t]
        
        # Extract the previous n_b values of U
        U_lags = cp.zeros((n_b,), dtype=U.dtype)
        if t >= n_b-1:
            U_lags[:] = U[t-n_b:t]
        U_lags = cp.tile(U_lags[None, :], (Y.shape[0], 1))
        # Concatenate Y_lags and U_lags to form phi_t
        phi_t = cp.concatenate([Y_lags, U_lags ], axis=1)
        # Store phi_t in the corresponding slice of phi
        print(t-max(n_a, n_b))
        phi[:, t, :] = phi_t

    return phi

def method_2(Y, U, n_a, n_b):
    """
    Constructs the phi array using vectorized operations.
    """
    m, t = Y.shape
    Y_lags = cp.array([Y[:, i - n_a:i] for i in range(n_a, t)])
    U_lags = cp.array([U[i - n_b:i] for i in range(n_b, t)])
    phi = cp.concatenate([Y_lags, U_lags], axis=-1)
    return phi

def method_3(Y, U, n_a, n_b):
    """
    Constructs the phi array using advanced indexing.
    """
    m, t = Y.shape
    Y_lags = cp.array([Y[:, i - n_a:i] for i in range(n_a, t)])
    U_lags = cp.array([U[i - n_b:i] for i in range(n_b, t)])
    phi = cp.concatenate([Y_lags, U_lags], axis=-1)
    return phi

def optimize_phi_calculation(Y, U, n_a, n_b):
    # Initialize phi with zeros
    phi = cp.zeros((Y.shape[0], Y.shape[1], n_a + n_b), dtype=Y.dtype)
    
    # Calculate the starting index for filling phi
    start_idx = max(n_a, n_b)
    
    # Create indices for Y lags
    y_indices = cp.arange(n_a)[None, :] + cp.arange(Y.shape[1] - start_idx)[:, None]
    
    # Fill Y lags in phi
    phi[:, start_idx:, :n_a] = Y[:, y_indices].transpose(0, 2, 1)
    
    # Create indices for U lags
    u_indices = cp.arange(n_b)[None, :] + cp.arange(Y.shape[1] - start_idx)[:, None]
    
    # Fill U lags in phi
    phi[:, start_idx:, n_a:] = cp.tile(U[u_indices], (Y.shape[0], 1, 1))

    return phi

# Usage
# Example data
m = 5  # Number of sequences
t = 20  # Length of each sequence
n_a = 3  # Number of previous values of Y
n_b = 2  # Number of previous values of U

Y_test = cp.random.rand(m, t)
U_test = cp.random.rand(t)

# List of methods to benchmark
methods = [method_1, method_2, method_3, optimize_phi_calculation]

# Benchmark each method
for method in methods:
    print(f"Benchmarking {method.__name__}:")
    print(method(Y_test, U_test, n_a, n_b))
    # result = benchmark(method, (Y_test, U_test, n_a, n_b), n_repeat=10)
    # print(result)
    # print()
# Out:
# Benchmarking method_1:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 73
#      71 for method in methods:
#      72     print(f"Benchmarking {method.__name__}:")
# ---> 73     print(method(Y_test, U_test, n_a, n_b))
#      74     # result = benchmark(method, (Y_test, U_test, n_a, n_b), n_repeat=10)
#      75     # print(result)
#      76     # print()
#
# Cell In[66], line 13, in method_1(Y, U, n_a, n_b)
#      11     Y_lags = Y[:, i - n_a:i]
#      12     U_lags = U[i - n_b:i]
# ---> 13     phi[:, i, :] = cp.concatenate([Y_lags, U_lags[None, :]], axis=1)
#      14 return phi
#
# File d:\mukul\Desktop\Unimelb\Masters\Capstone\Learning-Dynamic-Systems\.venv\Lib\site-packages\cupy\_manipulation\join.py:60, in concatenate(tup, axis, out, dtype, casting)
#      58     tup = [m.ravel() for m in tup]
#      59     axis = 0
# ---> 60 return _core.concatenate_method(tup, axis, out, dtype, casting)
#
# File cupy\_core\_routines_manipulation.pyx:586, in cupy._core._routines_manipulation.concatenate_method()
#
# File cupy\_core\_routines_manipulation.pyx:630, in cupy._core._routines_manipulation.concatenate_method()
#
# ValueError: All arrays must have same shape except the axis to concatenate

# %%
from cupyx.profiler import benchmark

# Define the dimensions
M = 1000  # Example value for M
N = 1000  # Example value for N

def method_choice():
    h = cp.random.choice([-1, 1], size=(M, N))
    h[0, :] = 1
    return h

def method_sign():
    random_array = cp.random.randn(M, N)
    h = cp.sign(random_array)
    h[0, :] = 1
    return h

def method_vstack():
    # Generate an (M-1)-by-N array of random numbers from a standard normal distribution
    random_array = cp.random.randn(M - 1, N)

    # Apply the sign function to obtain -1 or 1
    signed_random_array = cp.sign(random_array)

    # Prepend a row of ones
    ones_row = cp.ones((1, N))
    h = cp.vstack((ones_row, signed_random_array))
    return h

methods = [method_choice, method_sign, method_vstack]
n_repeat = 1000
for method in methods:
    print(f"Benchmarking {method.__name__}")
    print(benchmark(method, n_repeat=n_repeat))
# Out:
# Benchmarking method_choice
# method_choice       :    CPU:   788.355 us   +/- 235.711 (min:   449.900 / max:  1754.300) us     GPU-0:  2540.209 us   +/- 1028.177 (min:  2116.544 / max: 17078.497) us
# Benchmarking method_sign
# method_sign         :    CPU:   223.038 us   +/- 78.635 (min:   107.400 / max:   747.000) us     GPU-0:  1259.200 us   +/- 209.137 (min:  1134.208 / max:  3440.640) us
# Benchmarking method_vstack
# method_vstack       :    CPU:   370.047 us   +/- 114.688 (min:   203.600 / max:  1017.500) us     GPU-0:  1863.616 us   +/- 301.836 (min:  1689.120 / max:  4055.008) us

# %%
# Convert the results to a NumPy array
results = np.array(results)
# Plot the results
fig, ax = plt.subplots()
ax.plot(results[:, 0], results[:, 1], 'bo')  # Plot the points as blue dots

# Labeling the plot
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_title('Points for which open_loop_sps returns True')
ax.set_xlim([0.3, 0.5])
ax.set_ylim([-0.1, 0.5])
# Plot the true values
ax.plot(0.33, 0.22, 'ro')  # Plot the true values as a red dot

# Show the plot
plt.show()
